# %% [markdown]
# ## Web Scraping - Best Books of 2020s (Top 100)

# %% [markdown]
# #### Import relevant libraries

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# #### Getting response from website

# %%
url = 'https://www.goodreads.com/list/show/143500.Best_Books_of_the_Decade_2020_s'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"}
page = requests.get(url, headers=headers)
page
# Out:
# <Response [200]>

# %% [markdown]
# #### Getting the HTML script

# %%
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="desktop withSiteHeaderTopFullImage">
#  <head>
#   <title>
#    Best Books of the Decade: 2020's (2320 books)
#   </title>
#   <meta content="2,320 books based on 3888 votes: The Invisible Life of Addie LaRue by Victoria Schwab, The House in the Cerulean Sea by T.J. Klune, Project Hail Mary by ..." name="description"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="https://www.goodreads.com/list/show/143500.Best_Books_of_the_Decade_2020_s" rel="canonical"/>
#   <script type="text/javascript">
#    var ue_t0=window.ue_t0||+new Date();
#   </script>
#   <script type="text/javascript">
#    var ue_mid = "A1PQBFHBHS6YH1";
#     var ue_sn = "www.goodreads.com";
#     var ue_furl = "fls-na.amazon.com";
#     var ue_sid = "774-6633560-7856956";
#     var ue_id = "M1CP7BW4V3ZH9NHJAWTC";
#
#     (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);
#
#     if (window.ue && window.ue.tag) { window.ue.tag('list:show:signed_out', ue.main_scope);window.ue.tag('list:show:signed_out:desktop', ue.main_scope); }
#   </script>
#   <!-- * Copied from https://info.analytics.a2z.com/#/docs/data_collection/csa/onboard */ -->
#   <script>
#    //<![CDATA[
#     !function(){function n(n,t){var r=i(n);return t&&(r=r("instance",t)),r}var r=[],c=0,i=function(t){return function(){var n=c++;return r.push([t,[].slice.call(arguments,0),n,{time:Date.now()}]),i(n)}};n._s=r,this.csa=n}();
#
#     if (window.csa) {
#       window.csa("Config", {
#         "Application": "GoodreadsMonolith",
#         "Events.SushiEndpoint": "https://unagi.amazon.com/1/events/com.amazon.csm.csa.prod",
#         "Events.Namespace": "csa",
#         "CacheDetection.RequestID": "M1CP7BW4V3ZH9NHJAWTC",
#         "ObfuscatedMarketplaceId": "A1PQBFHBHS6YH1"
#       });
#
#       window.csa("Events")("setEntity", {
#         session: { id: "774-6633560-7856956" },
#         page: {requestId: "M1CP7BW4V3ZH9NHJAWTC", meaningful: "interactive"}
#       });
#     }
#
#     var e = document.createElement("script"); e.src = "https://m.media-amazon.com/images/I/41mrkPcyPwL.js"; document.head.appendChild(e);
#   //]]>
#   </script>
#   <script type="text/javascript">
#    if (window.Mobvious === undefined) {
#           window.Mobvious = {};
#         }
#         window.Mobvious.device_type = 'desktop';
#   </script>
#   <script src="https://s.gr-assets.com/assets/webfontloader-3aab2cc7a05633c1664e2b307cde7dec.js">
#   </script>
#   <script>
#    //<![CDATA[
#
#   WebFont.load({
#     classes: false,
#     custom: {
#       families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],
#       urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]
#     }
#   });
#
# //]]>
#   </script>
#   <link href="https://s.gr-assets.com/assets/goodreads-4d942452bb06f7c435ab0451fc2db2f5.css" media="all" rel="stylesheet">
#    <style media="screen" type="text/css">
#     .bigTabs {
#       margin-bottom: 10px;
#     }
#
#     .list_read{
#       background-color: #D7D2C4;
#       float: left;
#     }
#    </style>
#    <link href="https://s.gr-assets.com/assets/common_images-f5630939f2056b14f661a80fa8503dca.css" media="screen" rel="stylesheet"/>
#    <script src="https://s.gr-assets.com/assets/desktop/libraries-c07ee2e4be9ade4a64546b3ec60b523b.js">
#    </script>
#    <script src="https://s.gr-assets.com/assets/application-c9ca2b0a96b7d9468fe67c9b30eec3fc.js">
#    </script>
#    <script>
#     //<![CDATA[
#     var gptAdSlots = gptAdSlots || [];
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function() {
#       var gads = document.createElement("script");
#       gads.async = true;
#       gads.type = "text/javascript";
#       var useSSL = "https:" == document.location.protocol;
#       gads.src = (useSSL ? "https:" : "http:") +
#       "//securepubads.g.doubleclick.net/tag/js/gpt.js";
#       var node = document.getElementsByTagName("script")[0];
#       node.parentNode.insertBefore(gads, node);
#     })();
#     // page settings
#   //]]>
#    </script>
#    <script>
#     //<![CDATA[
#     googletag.cmd.push(function() {
#       googletag.pubads().setTargeting("sid", "osid.08f3c0f1235c247d7cf65e47dad9654e");
#     googletag.pubads().setTargeting("grsession", "osid.08f3c0f1235c247d7cf65e47dad9654e");
#     googletag.pubads().setTargeting("surface", "desktop");
#     googletag.pubads().setTargeting("signedin", "false");
#     googletag.pubads().setTargeting("gr_author", "false");
#     googletag.pubads().setTargeting("author", []);
#     googletag.pubads().setTargeting("shelf", ["2024","2023","2029","2021","2020","bydecade","2026","2022","2025","2020s","2028","2027"]);
#     googletag.pubads().setTargeting("tags", ["1669147","1228760","1669153","974125","410807","6611331","1669149","743121","1106498","410894","1230859","1669151"]);
#     googletag.pubads().setTargeting("gtargeting", "1");
#     googletag.pubads().setTargeting("resource", "List_143500");
#       googletag.pubads().enableAsyncRendering();
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.pubads().disableInitialLoad();
#       googletag.enableServices();
#     });
#   //]]>
#    </script>
#    <script>
#     //<![CDATA[
#     ! function(a9, a, p, s, t, A, g) {
#       if (a[a9]) return;
#
#       function q(c, r) {
#         a[a9]._Q.push([c, r])
#       }
#       a[a9] = {
#       init: function() {
#         q("i", arguments)
#       },
#       fetchBids: function() {
#         q("f", arguments)
#       },
#       setDisplayBids: function() {},
#         _Q: []
#       };
#       A = p.createElement(s);
#       A.async = !0;
#       A.src = t;
#       g = p.getElementsByTagName(s)[0];
#       g.parentNode.insertBefore(A, g)
#     }("apstag", window, document, "script", "//c.amazon-adsystem.com/aax2/apstag.js");
#
#     apstag.init({
#       pubID: '3211', adServer: 'googletag', bidTimeout: 4e3, deals: true, params: { aps_privacy: '1YN' }
#     });
#   //]]>
#    </script>
#    <meta content="authenticity_token" name="csrf-param">
#     <meta content="bN5YsPTwdfglJL3siAIjLLUrzpruy9pkU/j+73/MpBYFXxgBVSkazT5lkAK7DagTdrhAf197wEaHISzB8W5mbQ==" name="csrf-token">
#      <meta content="M1CP7BW4V3ZH9NHJAWTC" name="request-id"/>
#      <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/external_dependencies-2e2b90fafc.js">
#      </script>
#      <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/site_header-d3646670f3.js">
#      </script>
#      <script defer="defer" src="https://s.gr-assets.com/assets/react_client_side/custom_react_ujs-b1220d5e0a4820e90b905c302fc5cb52.js">
#      </script>
#      <script>
#       //<![CDATA[
#     $grfb.init.done(function() {
#       if (this.auth.status === "not_authorized") {
#         // logged into Facebook user but not a GR app user; show FB button
#         $j("#generalRegPrompt").hide();
#       } else {
#         $j("#facebookRegPrompt").hide();
#       }
#       $j("#connectPrompt").show();
#     });
#   //]]>
#      </script>
#      <link href="/opensearch.xml" rel="search" title="Goodreads" type="application/opensearchdescription+xml"/>
#      <meta content="2,320 books based on 3888 votes: The Invisible Life of Addie LaRue by Victoria Schwab, The House in the Cerulean Sea by T.J. Klune, Project Hail Mary by ..." name="description"/>
#      <meta content="summary" name="twitter:card"/>
#      <meta content="@goodreads" name="twitter:site"/>
#      <meta content="Best Books of the Decade: 2020's (2320 books)" name="twitter:title"/>
#      <meta content="2,320 books based on 3888 votes: The Invisible Life of Addie LaRue by Victoria Schwab, The House in the Cerulean Sea by T.J. Klune, Project Hail Mary by ..." name="twitter:description"/>
#      <meta content="cEf8XOH0pulh1aYQeZ1gkXHsQ3dMPSyIGGYqmF53690=" name="verify-v1"/>
#      <meta content="PfFjeZ9OK1RrUrKlmAPn_iZJ_vgHaZO1YQ-QlG2VsJs" name="google-site-verification">
#       <meta content="app-id=355833469" name="apple-itunes-app"/>
#      </meta>
#     </meta>
#    </meta>
#   </link>
#  </head>
#  <body class="">
#   <div data-react-class="ReactComponents.StoresInitializer" data-react-props="{}">
#    <noscript data-react-checksum="-1273360074" data-reactid=".10x1c4nvnfc">
#    </noscript>
#   </div>
#   <script src="https://s.gr-assets.com/assets/fb_dep_form-e2e4a0d9dc062011458143c32b2d789b.js">
#   </script>
#   <div class="content" id="bodycontainer" style="">
#    <script>
#     //<![CDATA[
#     var initializeGrfb = function() {
#       $grfb.initialize({
#         appId: "2415071772"
#       });
#     };
#     if (typeof $grfb !== "undefined") {
#       initializeGrfb();
#     } else {
#       window.addEventListener("DOMContentLoaded", function() {
#         if (typeof $grfb !== "undefined") {
#           initializeGrfb();
#         }
#       });
#     }
#   //]]>
#    </script>
#    <script>
#     //<![CDATA[
#     function loadScript(url, callback) {
#       var script = document.createElement("script");
#       script.type = "text/javascript";
#
#       if (script.readyState) {  //Internet Explorer
#           script.onreadystatechange = function() {
#             if (script.readyState == "loaded" ||
#                     script.readyState == "complete") {
#               script.onreadystatechange = null;
#               callback();
#             }
#           };
#       } else {  //Other browsers
#         script.onload = function() {
#           callback();
#         };
#       }
#
#       script.src = url;
#       document.getElementsByTagName("head")[0].appendChild(script);
#     }
#
#     function initAppleId() {
#       AppleID.auth.init({
#         clientId : 'com.goodreads.app',
#         scope : 'name email',
#         redirectURI: 'https://www.goodreads.com/apple_users/sign_in_with_apple_web',
#         state: 'apple_oauth_state_00543e61-d99b-4b56-bf11-59289fa0dbb5'
#       });
#     }
#
#     var initializeSiwa = function() {
#       var APPLE_SIGN_IN_JS_URL =  "https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/en_US/appleid.auth.js"
#       loadScript(APPLE_SIGN_IN_JS_URL, initAppleId);
#     };
#     if (typeof AppleID !== "undefined") {
#       initAppleId();
#     } else {
#       initializeSiwa();
#     }
#   //]]>
#    </script>
#    <div class="siteHeader">
#     <div data-react-class="ReactComponents.HeaderStoreConnector" data-react-props='{"myBooksUrl":"/review/list?ref=nav_mybooks","browseUrl":"/book?ref=nav_brws","recommendationsUrl":"/recommendations?ref=nav_brws_recs","choiceAwardsUrl":"/choiceawards?ref=nav_brws_gca","genresIndexUrl":"/genres?ref=nav_brws_genres","giveawayUrl":"/giveaway?ref=nav_brws_giveaways","exploreUrl":"/book?ref=nav_brws_explore","homeUrl":"/?ref=nav_home","listUrl":"/list?ref=nav_brws_lists","newsUrl":"/news?ref=nav_brws_news","communityUrl":"/group?ref=nav_comm","groupsUrl":"/group?ref=nav_comm_groups","quotesUrl":"/quotes?ref=nav_comm_quotes","featuredAskAuthorUrl":"/ask_the_author?ref=nav_comm_askauthor","autocompleteUrl":"/book/auto_complete","defaultLogoActionUrl":"/","topFullImage":{"clickthroughUrl":"https://www.goodreads.com/blog/show/2846?ref=tophorror24_eb","altText":"Top Horror from the Past Five Years","backgroundColor":"#707070","xs":{"1x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1727387722i/451.jpg","2x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1727387727i/452.jpg"},"md":{"1x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1727387711i/449.jpg","2x":"https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1727387716i/450.jpg"}},"logo":{"clickthroughUrl":"/","altText":"Goodreads Home"},"searchPath":"/search","newReleasesUrl":"/book/popular_by_date/2024/10?ref=nav_brws_newrels","signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","signInWithReturnUrl":true,"deployServices":[],"defaultLogoAltText":"Goodreads Home","mobviousDeviceType":"desktop"}'>
#      <header data-react-checksum="-1941676668" data-reactid=".1guzm6yq5so">
#       <div class="siteHeader__topFullImageContainer" data-reactid=".1guzm6yq5so.0" style="background-color:#707070;">
#        <a class="siteHeader__topFullImageLink" data-reactid=".1guzm6yq5so.0.0" href="https://www.goodreads.com/blog/show/2846?ref=tophorror24_eb">
#         <picture data-reactid=".1guzm6yq5so.0.0.0">
#          <source data-reactid=".1guzm6yq5so.0.0.0.0" media="(min-width: 768px)" srcset="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1727387711i/449.jpg 1x, https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1727387716i/450.jpg 2x"/>
#          <img alt="Top Horror from the Past Five Years" class="siteHeader__topFullImage" data-reactid=".1guzm6yq5so.0.0.0.1" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1727387722i/451.jpg" srcset="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/siteheaderbannerimages/1727387727i/452.jpg 2x"/>
#         </picture>
#        </a>
#       </div>
#       <div class="siteHeader__topLine gr-box gr-box--withShadow" data-reactid=".1guzm6yq5so.1">
#        <div class="siteHeader__contents" data-reactid=".1guzm6yq5so.1.0">
#         <div class="siteHeader__topLevelItem siteHeader__topLevelItem--searchIcon" data-reactid=".1guzm6yq5so.1.0.0">
#          <button aria-label="Toggle search" class="siteHeader__searchIcon gr-iconButton" data-reactid=".1guzm6yq5so.1.0.0.0" data-ux-click="true" type="button">
#          </button>
#         </div>
#         <a aria-label="Goodreads Home" class="siteHeader__logo" data-reactid=".1guzm6yq5so.1.0.1" href="/" title="Goodreads Home">
#         </a>
#         <nav class="siteHeader__primaryNavInline" data-reactid=".1guzm6yq5so.1.0.2">
#          <ul class="siteHeader__menuList" data-reactid=".1guzm6yq5so.1.0.2.0" role="menu">
#           <li class="siteHeader__topLevelItem siteHeader__topLevelItem--home" data-reactid=".1guzm6yq5so.1.0.2.0.0">
#            <a class="siteHeader__topLevelLink" data-reactid=".1guzm6yq5so.1.0.2.0.0.0" href="/?ref=nav_home">
#             Home
#            </a>
#           </li>
#           <li class="siteHeader__topLevelItem" data-reactid=".1guzm6yq5so.1.0.2.0.1">
#            <a class="siteHeader__topLevelLink" data-reactid=".1guzm6yq5so.1.0.2.0.1.0" href="/review/list?ref=nav_mybooks">
#             My Books
#            </a>
#           </li>
#           <li class="siteHeader__topLevelItem" data-reactid=".1guzm6yq5so.1.0.2.0.2">
#            <div class="primaryNavMenu primaryNavMenu--siteHeaderBrowseMenu ignore-react-onclickoutside" data-reactid=".1guzm6yq5so.1.0.2.0.2.0">
#             <a aria-expanded="false" aria-haspopup="true" class="primaryNavMenu__trigger primaryNavMenu__trigger--siteHeaderBrowseMenu" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.0" data-ux-click="true" href="/book?ref=nav_brws" role="button">
#              <span data-reactid=".1guzm6yq5so.1.0.2.0.2.0.0.0">
#               Browse ▾
#              </span>
#             </a>
#             <div class="primaryNavMenu__menu gr-box gr-box--withShadowLarge wide" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1" role="menu">
#              <div class="siteHeader__browseMenuDropdown" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0">
#               <ul class="siteHeader__subNav" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0">
#                <li aria-label="Recommendations" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.0" role="menuitem Recommendations">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.0.0" href="/recommendations?ref=nav_brws_recs">
#                  Recommendations
#                 </a>
#                </li>
#                <li aria-label="Choice Awards" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.1" role="menuitem Choice Awards">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.1.0" href="/choiceawards?ref=nav_brws_gca">
#                  Choice Awards
#                 </a>
#                </li>
#                <li aria-label="Genres" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.2" role="menuitem Genres">
#                 <a class="siteHeader__subNavLink siteHeader__subNavLink--genresIndex" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.2.0" href="/genres?ref=nav_brws_genres">
#                  Genres
#                 </a>
#                </li>
#                <li aria-label="Giveaways" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.3" role="menuitem Giveaways">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.3.0" href="/giveaway?ref=nav_brws_giveaways">
#                  Giveaways
#                 </a>
#                </li>
#                <li aria-label="New Releases" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.4" role="menuitem New Releases">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.4.0" href="/book/popular_by_date/2024/10?ref=nav_brws_newrels">
#                  New Releases
#                 </a>
#                </li>
#                <li aria-label="Lists" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.5" role="menuitem Lists">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.5.0" href="/list?ref=nav_brws_lists">
#                  Lists
#                 </a>
#                </li>
#                <li aria-label="Explore" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.6" role="menuitem Explore">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.6.0" href="/book?ref=nav_brws_explore">
#                  Explore
#                 </a>
#                </li>
#                <li aria-label="News &amp; Interviews" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.7" role="menuitem News &amp; Interviews">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.0.7.0" href="/news?ref=nav_brws_news">
#                  News &amp; Interviews
#                 </a>
#                </li>
#               </ul>
#               <div class="siteHeader__spotlight siteHeader__spotlight--withoutSubMenu" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1">
#                <div class="genreListContainer" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0">
#                 <div class="siteHeader__heading siteHeader__title" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.0">
#                  Genres
#                 </div>
#                 <ul class="genreList" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0">
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Art" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Art.0" href="/genres/art">
#                    Art
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Biography" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Biography.0" href="/genres/biography">
#                    Biography
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Business" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Business.0" href="/genres/business">
#                    Business
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Children's" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Children's.0" href="/genres/children-s">
#                    Children's
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Christian" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Christian.0" href="/genres/christian">
#                    Christian
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Classics" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Classics.0" href="/genres/classics">
#                    Classics
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Comics" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Comics.0" href="/genres/comics">
#                    Comics
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Cookbooks" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Cookbooks.0" href="/genres/cookbooks">
#                    Cookbooks
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Ebooks" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Ebooks.0" href="/genres/ebooks">
#                    Ebooks
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Fantasy" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList0.0:$Fantasy.0" href="/genres/fantasy">
#                    Fantasy
#                   </a>
#                  </li>
#                 </ul>
#                 <ul class="genreList" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1">
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Fiction" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Fiction.0" href="/genres/fiction">
#                    Fiction
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Graphic Novels" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Graphic Novels.0" href="/genres/graphic-novels">
#                    Graphic Novels
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Historical Fiction" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Historical Fiction.0" href="/genres/historical-fiction">
#                    Historical Fiction
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$History" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$History.0" href="/genres/history">
#                    History
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Horror" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Horror.0" href="/genres/horror">
#                    Horror
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Memoir" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Memoir.0" href="/genres/memoir">
#                    Memoir
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Music" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Music.0" href="/genres/music">
#                    Music
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Mystery" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Mystery.0" href="/genres/mystery">
#                    Mystery
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Nonfiction" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Nonfiction.0" href="/genres/non-fiction">
#                    Nonfiction
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Poetry" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList1.0:$Poetry.0" href="/genres/poetry">
#                    Poetry
#                   </a>
#                  </li>
#                 </ul>
#                 <ul class="genreList" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2">
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Psychology" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Psychology.0" href="/genres/psychology">
#                    Psychology
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Romance" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Romance.0" href="/genres/romance">
#                    Romance
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Science" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Science.0" href="/genres/science">
#                    Science
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Science Fiction" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Science Fiction.0" href="/genres/science-fiction">
#                    Science Fiction
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Self Help" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Self Help.0" href="/genres/self-help">
#                    Self Help
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Sports" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Sports.0" href="/genres/sports">
#                    Sports
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Thriller" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Thriller.0" href="/genres/thriller">
#                    Thriller
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Travel" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Travel.0" href="/genres/travel">
#                    Travel
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Young Adult" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.0:$Young Adult.0" href="/genres/young-adult">
#                    Young Adult
#                   </a>
#                  </li>
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.1" role="menuitem">
#                   <a class="genreList__genreLink gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.2.0.2.0.1.0.1.0.1:$genreList2.1.0" href="/genres">
#                    More Genres
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <li class="siteHeader__topLevelItem siteHeader__topLevelItem--community" data-reactid=".1guzm6yq5so.1.0.2.0.3">
#            <div class="primaryNavMenu ignore-react-onclickoutside" data-reactid=".1guzm6yq5so.1.0.2.0.3.0">
#             <a aria-expanded="false" aria-haspopup="true" class="primaryNavMenu__trigger" data-reactid=".1guzm6yq5so.1.0.2.0.3.0.0" data-ux-click="true" href="/group?ref=nav_comm" role="button">
#              <span data-reactid=".1guzm6yq5so.1.0.2.0.3.0.0.0">
#               Community ▾
#              </span>
#             </a>
#             <div class="primaryNavMenu__menu gr-box gr-box--withShadowLarge" data-reactid=".1guzm6yq5so.1.0.2.0.3.0.1" role="menu">
#              <ul class="siteHeader__subNav" data-reactid=".1guzm6yq5so.1.0.2.0.3.0.1.0">
#               <li aria-label="Groups" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.3.0.1.0.0" role="menuitem Groups">
#                <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.2.0.3.0.1.0.0.0" href="/group?ref=nav_comm_groups">
#                 Groups
#                </a>
#               </li>
#               <li aria-label="Quotes" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.3.0.1.0.2" role="menuitem Quotes">
#                <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.2.0.3.0.1.0.2.0" href="/quotes?ref=nav_comm_quotes">
#                 Quotes
#                </a>
#               </li>
#               <li aria-label="Ask the Author" class="menuLink" data-reactid=".1guzm6yq5so.1.0.2.0.3.0.1.0.3" role="menuitem Ask the Author">
#                <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.2.0.3.0.1.0.3.0" href="/ask_the_author?ref=nav_comm_askauthor">
#                 Ask the Author
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </li>
#          </ul>
#         </nav>
#         <div accept-charset="UTF-8" class="searchBox searchBox--navbar" data-reactid=".1guzm6yq5so.1.0.3">
#          <form action="/search" aria-label="Search for books to add to your shelves" autocomplete="off" class="searchBox__form" data-reactid=".1guzm6yq5so.1.0.3.0" role="search">
#           <input aria-controls="searchResults" aria-label="Search books" autocomplete="off" class="searchBox__input searchBox__input--navbar" data-reactid=".1guzm6yq5so.1.0.3.0.0" name="q" placeholder="Search books" type="text"/>
#           <input data-reactid=".1guzm6yq5so.1.0.3.0.1" name="qid" type="hidden" value=""/>
#           <button aria-label="Search" class="searchBox__icon--magnifyingGlass gr-iconButton searchBox__icon searchBox__icon--navbar" data-reactid=".1guzm6yq5so.1.0.3.0.2" type="submit">
#           </button>
#          </form>
#         </div>
#         <ul class="siteHeader__personal" data-reactid=".1guzm6yq5so.1.0.4">
#          <li class="siteHeader__topLevelItem siteHeader__topLevelItem--signedOut" data-reactid=".1guzm6yq5so.1.0.4.0">
#           <a class="siteHeader__topLevelLink" data-reactid=".1guzm6yq5so.1.0.4.0.0" href="/user/sign_in?returnurl=undefined" rel="nofollow">
#            Sign In
#           </a>
#          </li>
#          <li class="siteHeader__topLevelItem siteHeader__topLevelItem--signedOut" data-reactid=".1guzm6yq5so.1.0.4.1">
#           <a class="siteHeader__topLevelLink" data-reactid=".1guzm6yq5so.1.0.4.1.0" href="/user/sign_up" rel="nofollow">
#            Join
#           </a>
#          </li>
#         </ul>
#         <div class="siteHeader__topLevelItem siteHeader__topLevelItem--signUp" data-reactid=".1guzm6yq5so.1.0.5">
#          <a class="gr-button gr-button--dark" data-reactid=".1guzm6yq5so.1.0.5.0" href="/user/sign_up" rel="nofollow">
#           Sign up
#          </a>
#         </div>
#         <div class="modal modal--overlay modal--drawer" data-reactid=".1guzm6yq5so.1.0.7" tabindex="0">
#          <div data-reactid=".1guzm6yq5so.1.0.7.0">
#           <div class="modal__close" data-reactid=".1guzm6yq5so.1.0.7.0.0">
#            <button class="gr-iconButton" data-reactid=".1guzm6yq5so.1.0.7.0.0.0" type="button">
#             <img alt="Dismiss" data-reactid=".1guzm6yq5so.1.0.7.0.0.0.0" src="//s.gr-assets.com/assets/gr/icons/icon_close_white-dbf4152deeef5bd3915d5d12210bf05f.svg"/>
#            </button>
#           </div>
#           <div class="modal__content" data-reactid=".1guzm6yq5so.1.0.7.0.1">
#            <div class="personalNavDrawer" data-reactid=".1guzm6yq5so.1.0.7.0.1.0">
#             <div class="personalNavDrawer__personalNavContainer" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.0">
#              <noscript data-reactid=".1guzm6yq5so.1.0.7.0.1.0.0.0">
#              </noscript>
#             </div>
#             <div class="personalNavDrawer__profileAndLinksContainer" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1">
#              <div class="personalNavDrawer__profileContainer gr-mediaFlexbox gr-mediaFlexbox--alignItemsCenter" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.0">
#               <div class="gr-mediaFlexbox__media" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.0.0">
#                <img class="circularIcon circularIcon--large circularIcon--border" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.0.0.0"/>
#               </div>
#               <div class="gr-mediaFlexbox__desc" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.0.1">
#                <a class="gr-hyperlink gr-hyperlink--bold" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.0.1.0">
#                </a>
#                <div class="u-displayBlock" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.0.1.1">
#                 <a class="gr-hyperlink gr-hyperlink--naked" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.0.1.1.0">
#                  View profile
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="personalNavDrawer__profileMenuContainer" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1">
#               <ul data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0">
#                <li aria-label="Profile" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.0" role="menuitem Profile">
#                 <span data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.0.0">
#                  <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.0.0.0">
#                   Profile
#                  </a>
#                 </span>
#                </li>
#                <li aria-label="Friends" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.3" role="menuitem Friends">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.3.0">
#                  Friends
#                 </a>
#                </li>
#                <li aria-label="Groups" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.4" role="menuitem Groups">
#                 <span data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.4.0">
#                  <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.4.0.0">
#                   <span data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.4.0.0.0">
#                    Groups
#                   </span>
#                  </a>
#                 </span>
#                </li>
#                <li aria-label="Discussions" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.5" role="menuitem Discussions">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.5.0">
#                  Discussions
#                 </a>
#                </li>
#                <li aria-label="Comments" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.6" role="menuitem Comments">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.6.0">
#                  Comments
#                 </a>
#                </li>
#                <li aria-label="Reading Challenge" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.7" role="menuitem Reading Challenge">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.7.0">
#                  Reading Challenge
#                 </a>
#                </li>
#                <li aria-label="Kindle Notes &amp; Highlights" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.8" role="menuitem Kindle Notes &amp; Highlights">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.8.0">
#                  Kindle Notes &amp; Highlights
#                 </a>
#                </li>
#                <li aria-label="Quotes" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.9" role="menuitem Quotes">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.9.0">
#                  Quotes
#                 </a>
#                </li>
#                <li aria-label="Favorite genres" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.a" role="menuitem Favorite genres">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.a.0">
#                  Favorite genres
#                 </a>
#                </li>
#                <li aria-label="Friends' recommendations" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.b" role="menuitem Friends' recommendations">
#                 <span data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.b.0">
#                  <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.b.0.0">
#                   <span data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.b.0.0.0">
#                    Friends’ recommendations
#                   </span>
#                  </a>
#                 </span>
#                </li>
#                <li aria-label="Account settings" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.c" role="menuitem Account settings">
#                 <a class="siteHeader__subNavLink u-topGrayBorder" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.c.0">
#                  Account settings
#                 </a>
#                </li>
#                <li aria-label="Help" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.d" role="menuitem Help">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.d.0">
#                  Help
#                 </a>
#                </li>
#                <li aria-label="Sign out" class="menuLink" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.e" role="menuitem Sign out">
#                 <a class="siteHeader__subNavLink" data-method="POST" data-reactid=".1guzm6yq5so.1.0.7.0.1.0.1.1.0.e.0">
#                  Sign out
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="headroom-wrapper" data-reactid=".1guzm6yq5so.2">
#        <div class="headroom headroom--unfixed" data-reactid=".1guzm6yq5so.2.0" style="position:relative;top:0;left:0;right:0;z-index:1;-webkit-transform:translateY(0);-ms-transform:translateY(0);transform:translateY(0);">
#         <nav class="siteHeader__primaryNavSeparateLine gr-box gr-box--withShadow" data-reactid=".1guzm6yq5so.2.0.0">
#          <ul class="siteHeader__menuList" data-reactid=".1guzm6yq5so.2.0.0.0" role="menu">
#           <li class="siteHeader__topLevelItem siteHeader__topLevelItem--home" data-reactid=".1guzm6yq5so.2.0.0.0.0">
#            <a class="siteHeader__topLevelLink" data-reactid=".1guzm6yq5so.2.0.0.0.0.0" href="/?ref=nav_home">
#             Home
#            </a>
#           </li>
#           <li class="siteHeader__topLevelItem" data-reactid=".1guzm6yq5so.2.0.0.0.1">
#            <a class="siteHeader__topLevelLink" data-reactid=".1guzm6yq5so.2.0.0.0.1.0" href="/review/list?ref=nav_mybooks">
#             My Books
#            </a>
#           </li>
#           <li class="siteHeader__topLevelItem" data-reactid=".1guzm6yq5so.2.0.0.0.2">
#            <div class="primaryNavMenu primaryNavMenu--siteHeaderBrowseMenu ignore-react-onclickoutside" data-reactid=".1guzm6yq5so.2.0.0.0.2.0">
#             <a aria-expanded="false" aria-haspopup="true" class="primaryNavMenu__trigger primaryNavMenu__trigger--siteHeaderBrowseMenu" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.0" data-ux-click="true" href="/book?ref=nav_brws" role="button">
#              <span data-reactid=".1guzm6yq5so.2.0.0.0.2.0.0.0">
#               Browse ▾
#              </span>
#             </a>
#             <div class="primaryNavMenu__menu gr-box gr-box--withShadowLarge wide" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1" role="menu">
#              <div class="siteHeader__browseMenuDropdown" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0">
#               <ul class="siteHeader__subNav" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0">
#                <li aria-label="Recommendations" class="menuLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.0" role="menuitem Recommendations">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.0.0" href="/recommendations?ref=nav_brws_recs">
#                  Recommendations
#                 </a>
#                </li>
#                <li aria-label="Choice Awards" class="menuLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.1" role="menuitem Choice Awards">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.1.0" href="/choiceawards?ref=nav_brws_gca">
#                  Choice Awards
#                 </a>
#                </li>
#                <li aria-label="Genres" class="menuLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.2" role="menuitem Genres">
#                 <a class="siteHeader__subNavLink siteHeader__subNavLink--genresIndex" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.2.0" href="/genres?ref=nav_brws_genres">
#                  Genres
#                 </a>
#                </li>
#                <li aria-label="Giveaways" class="menuLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.3" role="menuitem Giveaways">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.3.0" href="/giveaway?ref=nav_brws_giveaways">
#                  Giveaways
#                 </a>
#                </li>
#                <li aria-label="New Releases" class="menuLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.4" role="menuitem New Releases">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.4.0" href="/book/popular_by_date/2024/10?ref=nav_brws_newrels">
#                  New Releases
#                 </a>
#                </li>
#                <li aria-label="Lists" class="menuLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.5" role="menuitem Lists">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.5.0" href="/list?ref=nav_brws_lists">
#                  Lists
#                 </a>
#                </li>
#                <li aria-label="Explore" class="menuLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.6" role="menuitem Explore">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.6.0" href="/book?ref=nav_brws_explore">
#                  Explore
#                 </a>
#                </li>
#                <li aria-label="News &amp; Interviews" class="menuLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.7" role="menuitem News &amp; Interviews">
#                 <a class="siteHeader__subNavLink" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.0.7.0" href="/news?ref=nav_brws_news">
#                  News &amp; Interviews
#                 </a>
#                </li>
#               </ul>
#               <div class="siteHeader__spotlight siteHeader__spotlight--withoutSubMenu" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.1">
#                <div class="genreListContainer" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.1.0">
#                 <div class="siteHeader__heading siteHeader__title" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.1.0.0">
#                  Genres
#                 </div>
#                 <ul class="genreList" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.1.0.1:$genreList0">
#                  <li class="genreList__genre" data-reactid=".1guzm6yq5so.2.0.0.0.2.0.1.0.1.0.1:$genreList0.0:$Art" role="menuitem">
# ...
#               </div>
#               <div class="action right">
#                <a class="actionLinkLite" href="/blog/show/2835-the-past-year-s-biggest-mystery-thriller-hits">
#                 Read »
#                </a>
#               </div>
#              </div>
#              <br class="clear"/>
#              <div style="border:1px solid grey;">
#              </div>
#              <div class="clear">
#              </div>
#             </div>
#             <a class="actionLink right" href="/news">
#              More articles…
#             </a>
#             <div class="clear">
#             </div>
#            </div>
#           </div>
#           <div class="bigBoxBottom">
#           </div>
#          </div>
#         </div>
#        </div>
#        <ul class="listHeaderLinks stacked">
#         <li>
#          <a class="actionLinkLite" href="/list/new">
#           Create New List
#          </a>
#         </li>
#         <li>
#          <a class="actionLinkLite" href="/list">
#           All Lists
#          </a>
#         </li>
#         <li>
#          <a class="actionLinkLite" href="/list/created">
#           Lists I Created
#          </a>
#         </li>
#         <li>
#          <a class="actionLinkLite" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F143500.Best_Books_of_the_Decade_2020_s">
#           Lists I've Voted On
#          </a>
#         </li>
#         <li>
#          <a class="actionLinkLite" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F143500.Best_Books_of_the_Decade_2020_s">
#           Lists I've Liked
#          </a>
#         </li>
#        </ul>
#        <p class="mediumText">
#         Anyone can add books to this list.
#        </p>
#        <p>
#        </p>
#        <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"","className":"googleBannerAd--mediumRectangle"}'>
#        </div>
#        <div data-react-class="ReactComponents.GoogleFeaturedContentModule" data-react-props='{"adId":"","trackingOptions":{"enableTracking":true,"adId":""},"isMobile":false,"isInline":false,"hasBottomBorder":false}'>
#        </div>
#        <div class="clearFloats bigBox">
#         <div class="h2Container gradientHeaderContainer">
#          <h2 class="brownBackground">
#           <div class="extraHeader">
#            <span id="saving_notice" style="display:none">
#             Saving
#             <img alt="Loading trans" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
#            </span>
#           </div>
#           <a href="/list/show/143500.Best_Books_of_the_Decade_2020_s">
#            My Votes
#           </a>
#          </h2>
#         </div>
#         <div class="bigBoxBody">
#          <div class="bigBoxContent containerWithHeaderContent">
#           <a class="actionLink" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F143500.Best_Books_of_the_Decade_2020_s">
#            vote now
#           </a>
#           <div class="clear">
#           </div>
#          </div>
#         </div>
#         <div class="bigBoxBottom">
#         </div>
#        </div>
#        <br class="clear">
#         <br/>
#         <div class="clearFloats bigBox">
#          <div class="h2Container gradientHeaderContainer">
#           <h2 class="brownBackground">
#            <a href="/list/invite/143500.Best_Books_of_the_Decade_2020_s">
#             Friends Votes
#            </a>
#           </h2>
#          </div>
#          <div class="bigBoxBody">
#           <div class="bigBoxContent containerWithHeaderContent">
#            <a class="actionLink" href="https://www.goodreads.com/user/new?remember=true&amp;return_url=%2Flist%2Fshow%2F143500.Best_Books_of_the_Decade_2020_s">
#             get your friends to vote
#            </a>
#            <div class="clear">
#            </div>
#           </div>
#          </div>
#          <div class="bigBoxBottom">
#          </div>
#         </div>
#         <div data-react-class="ReactComponents.GoogleBannerAd" data-react-props='{"adId":"","className":"googleBannerAd--mediumRectangle"}'>
#         </div>
#        </br>
#       </div>
#       <div id="chooseExplanation" style="display:none">
#        <h2>
#         How to Vote
#        </h2>
#        <p>
#         To vote on existing books from the list, beside each book there is a link
#         <span class="gr-button gr-button--small">
#          vote for this book
#         </span>
#         clicking it will add that book to your votes.
#        </p>
#        <p>
#         To vote on books not in the list or books you couldn't find in the list, you can click on the tab
#         <span class="bigTabs">
#          <span class="tab">
#           add books to this list
#          </span>
#         </span>
#         and then choose from your books, or simply search.
#        </p>
#       </div>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#     <div class="clear">
#     </div>
#    </div>
#    <div data-react-class="ReactComponents.GooglePageSkin" data-react-props='{"adId":"","trackingOptions":{"enableTracking":true,"adId":""}}'>
#    </div>
#    <div class="clear">
#    </div>
#    <footer class="responsiveSiteFooter">
#     <div class="responsiveSiteFooter__contents gr-container-fluid">
#      <div class="gr-row">
#       <div class="gr-col gr-col-md-8 gr-col-lg-6">
#        <div class="gr-row">
#         <div class="gr-col-md-3 gr-col-lg-4">
#          <h3 class="responsiveSiteFooter__heading">
#           Company
#          </h3>
#          <ul class="responsiveSiteFooter__linkList">
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/about/us">
#             About us
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/jobs">
#             Careers
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/about/terms">
#             Terms
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/about/privacy">
#             Privacy
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="https://help.goodreads.com/s/article/Goodreads-Interest-Based-Ads-Notice">
#             Interest Based Ads
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/adprefs">
#             Ad Preferences
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/help?action_type=help_web_footer">
#             Help
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="gr-col-md-4 gr-col-lg-4">
#          <h3 class="responsiveSiteFooter__heading">
#           Work with us
#          </h3>
#          <ul class="responsiveSiteFooter__linkList">
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/author/program">
#             Authors
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/advertisers">
#             Advertise
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/news?content_type=author_blogs">
#             Authors &amp; ads blog
#            </a>
#           </li>
#           <li class="responsiveSiteFooter__linkListItem">
#            <a class="responsiveSiteFooter__link" href="/api">
#             API
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="gr-col-md-5 gr-col-lg-4">
#          <h3 class="responsiveSiteFooter__heading">
#           Connect
#          </h3>
#          <div class="responsiveSiteFooter__socialLinkWrapper">
#           <a class="responsiveSiteFooter__socialLink" href="https://www.facebook.com/Goodreads/" rel="noopener noreferrer">
#            <img alt="Goodreads on Facebook" src="https://s.gr-assets.com/assets/site_footer/footer_facebook-ea4ab848f8e86c5f5c98311bc9495a1b.svg"/>
#           </a>
#           <a class="responsiveSiteFooter__socialLink" href="https://twitter.com/goodreads" rel="noopener noreferrer">
#            <img alt="Goodreads on Twitter" src="https://s.gr-assets.com/assets/site_footer/footer_twitter-126b3ee80481a763f7fccb06ca03053c.svg"/>
#           </a>
#          </div>
#          <div class="responsiveSiteFooter__socialLinkWrapper">
#           <a class="responsiveSiteFooter__socialLink" href="https://www.instagram.com/goodreads/" rel="noopener noreferrer">
#            <img alt="Goodreads on Instagram" src="https://s.gr-assets.com/assets/site_footer/footer_instagram-d59e3887020f12bcdb12e6c539579d85.svg"/>
#           </a>
#           <a class="responsiveSiteFooter__socialLink" href="https://www.linkedin.com/company/goodreads-com/" rel="noopener noreferrer">
#            <img alt="Goodreads on LinkedIn" src="https://s.gr-assets.com/assets/site_footer/footer_linkedin-5b820f4703eff965672594ef4d10e33c.svg"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="gr-col gr-col-md-4 gr-col-lg-6 responsiveSiteFooter__appLinksColumn">
#        <div class="responsiveSiteFooter__appLinksColumnContents">
#         <div class="responsiveSiteFooter__appLinksColumnBadges">
#          <a href="https://itunes.apple.com/app/apple-store/id355833469?pt=325668&amp;ct=mw_footer&amp;mt=8">
#           <img alt="Download app for iOS" src="https://s.gr-assets.com/assets/app/badge-ios-desktop-homepage-6ac7ae16eabce57f6c855361656a7540.svg"/>
#          </a>
#          <a href="https://play.google.com/store/apps/details?id=com.goodreads&amp;utm_source=mw_footer&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-PartBadge-Mar2515-1">
#           <img alt="Download app for Android" src="https://s.gr-assets.com/assets/app/badge-android-desktop-home-0f517cbae4d56c88a128d27a7bea1118.png" srcset="https://s.gr-assets.com/assets/app/badge-android-desktop-home-2x-e31514e1fb4dddecf9293aa526a64cfe.png 2x"/>
#          </a>
#         </div>
#         <ul class="responsiveSiteFooter__linkList">
#          <li class="responsiveSiteFooter__linkListItem">
#           ©
# 2024
# Goodreads, Inc.
#          </li>
#          <li class="responsiveSiteFooter__linkListItem">
#           <a class="responsiveSiteFooter__link" href="/toggle_mobile">
#            Mobile version
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </footer>
#    <script>
#     //<![CDATA[
# if (typeof window.uet == 'function') { window.uet('be'); }
# //]]>
#    </script>
#   </div>
#   <!--
# This partial loads on almost every page view.  The associated React component makes
# a call to SignInPromptController#get to determine if the user should see the sign in interstial.
# This is determined by how many signed out pagehits the user has executed an how recently they have
# last seen the insterstitial.  If the controller responds indicating the popup should appear, the
# React component will render its content.
# -->
#   <div data-react-class="ReactComponents.LoginInterstitial" data-react-props='{"allowFacebookSignIn":true,"allowAmazonSignIn":true,"overrideSignedOutPageCount":false,"path":{"signInUrl":"/user/sign_in","signUpUrl":"/user/sign_up","privacyUrl":"/about/privacy","termsUrl":"/about/terms","thirdPartyRedirectUrl":"/user/new?connect_prompt=true"}}'>
#    <noscript data-react-checksum="-1221455548" data-reactid=".1tdn21xtfn0">
#    </noscript>
#   </div>
#   <div id="overlay" onclick="Lightbox.hideBox()" style="display:none">
#   </div>
#   <div id="box" style="display:none">
#    <div class="xBackground js-closeModalIcon" id="close" onclick="Lightbox.hideBox()" title="Close this window">
#    </div>
#    <div id="boxContents">
#    </div>
#    <div id="boxContentsLeftovers" style="display:none">
#    </div>
#    <div class="clear">
#    </div>
#   </div>
#   <div id="fbSigninNotification" style="display:none;">
#    <p>
#     Welcome back. Just a moment while we sign you in to your Goodreads account.
#    </p>
#    <img alt="Login animation" src="https://s.gr-assets.com/assets/facebook/login_animation-085464711e6c1ed5ba287a2f40ba3343.gif"/>
#   </div>
#   <script>
#    //<![CDATA[
#     qcdata = {} || qcdata;
#       (function(){
#         var elem = document.createElement('script');
#         elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-0dUe_kJAjvkoY";
#         elem.async = true;
#         elem.type = "text/javascript";
#         var scpt = document.getElementsByTagName('script')[0];
#         scpt.parentNode.insertBefore(elem,scpt);
#       }());
#     var qcdata = {qacct: 'p-0dUe_kJAjvkoY'};
#   //]]>
#   </script>
#   <noscript>
#    <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-0dUe_kJAjvkoY.gif" style="display: none;" width="1"/>
#   </noscript>
#   <script>
#    //<![CDATA[
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "6035830", c3: "", c4: "", c5: "", c6: "", c15: ""});
#     (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#     })();
#   //]]>
#   </script>
#   <noscript>
#    <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;amp;c2=6035830&amp;amp;c3=&amp;amp;c4=&amp;amp;c5=&amp;amp;c6=&amp;amp;c15=&amp;amp;cv=2.0&amp;amp;cj=1" style="display: none" width="0">
#    </img>
#   </noscript>
#   <script>
#    //<![CDATA[
#     window.addEventListener("DOMContentLoaded", function() {
#       ReactStores.GoogleAdsStore.initializeWith({"targeting":{"sid":"osid.08f3c0f1235c247d7cf65e47dad9654e","grsession":"osid.08f3c0f1235c247d7cf65e47dad9654e","surface":"desktop","signedin":"false","gr_author":"false","author":[],"shelf":["2023","2020s","bestbydecade","2024","2029","2020","2022","2027","2026","2025","2021","2028"],"tags":["1228760","410894","1669147","1669153","410807","743121","1669151","1669149","1106498","974125","1230859"],"gtargeting":"1","resource":"List_143500"},"ads":{},"nativeAds":{}});  ReactStores.NotificationsStore.updateWith({});
#       ReactStores.CurrentUserStore.initializeWith({"currentUser":null});
#       ReactStores.FavoriteGenresStore.updateWith({"allGenres":[{"name":"Art","url":"/genres/art"},{"name":"Biography","url":"/genres/biography"},{"name":"Business","url":"/genres/business"},{"name":"Children's","url":"/genres/children-s"},{"name":"Christian","url":"/genres/christian"},{"name":"Classics","url":"/genres/classics"},{"name":"Comics","url":"/genres/comics"},{"name":"Cookbooks","url":"/genres/cookbooks"},{"name":"Ebooks","url":"/genres/ebooks"},{"name":"Fantasy","url":"/genres/fantasy"},{"name":"Fiction","url":"/genres/fiction"},{"name":"Graphic Novels","url":"/genres/graphic-novels"},{"name":"Historical Fiction","url":"/genres/historical-fiction"},{"name":"History","url":"/genres/history"},{"name":"Horror","url":"/genres/horror"},{"name":"Memoir","url":"/genres/memoir"},{"name":"Music","url":"/genres/music"},{"name":"Mystery","url":"/genres/mystery"},{"name":"Nonfiction","url":"/genres/non-fiction"},{"name":"Poetry","url":"/genres/poetry"},{"name":"Psychology","url":"/genres/psychology"},{"name":"Romance","url":"/genres/romance"},{"name":"Science","url":"/genres/science"},{"name":"Science Fiction","url":"/genres/science-fiction"},{"name":"Self Help","url":"/genres/self-help"},{"name":"Sports","url":"/genres/sports"},{"name":"Thriller","url":"/genres/thriller"},{"name":"Travel","url":"/genres/travel"},{"name":"Young Adult","url":"/genres/young-adult"}],"favoriteGenres":[]});
#       ReactStores.TabsStore.updateWith({"communitySpotlight":"groups"});
#
#     });
#   //]]>
#   </script>
#  </body>
# </html>
# <!-- This is a random-length HTML comment: ... -->

# %% [markdown]
# #### Storing the script in a table.
# Since the data is stored in an HTML table, it's best to find it by searching the table

# %%
main_table = soup.find('table', class_ = 'tableList js-dataTooltip')
main_table
# Out:
# <table class="tableList js-dataTooltip">
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">1</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="50623864"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="50623864" data-resource-type="Book">
# <a href="/book/show/50623864-the-invisible-life-of-addie-larue" title="The Invisible Life of Addie LaRue">
# <img alt="The Invisible Life of Addie..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1584633432i/50623864._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/50623864-the-invisible-life-of-addie-larue" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">The Invisible Life of Addie LaRue</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/3099544.Victoria_Schwab" itemprop="url"><span itemprop="name">Victoria Schwab</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.18 avg rating — 1,176,362 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 61,052</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_678014" onclick="new Ajax.Request('/list/list_book/9798124', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_678014');$('loading_link_678014').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_678014').show();;Element.hide('loading_anim_678014');}, onLoading:function(request){;Element.show('loading_anim_678014');Element.hide('loading_link_678014')}, onSuccess:function(request){Element.hide('loading_anim_678014');Element.show('loading_link_678014');}, parameters:'authenticity_token=' + encodeURIComponent('lGcc6XAgtXYzuygSkv+6IQTqgClJ8mI+QsyOsmkwR2D95lxY0fnaQyj6Bfyh8DEex3kOzPhCeByWFVyc55KFGw==')}); return false;">618 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_678014" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="1_book_50623864">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="StFVh5UBW+EkO40/X74d7VeqxXb37TwroWRYVqKlVVIjUBU2NNg01D96oNFssZbSlDlLk0ZdJgl1vYp4LAeXKQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="50623864"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_50623864"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ToIgAfY+W23oXlYTon4qOxZw6/Dj0zLEZFx1hO31rh4nA2CwV+c0WPMfe/2RcaEE1eNlFVJjKOawhaeqY1dsZQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_50623864"/>
# <input id="book_id" name="book_id" type="hidden" value="50623864"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# <div class="wtrShelfMenu">
# <ul class="wtrExclusiveShelves">
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="to-read">
# <span class="progressTrigger">Want to Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="currently-reading">
# <span class="progressTrigger">Currently Reading</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="read">
# <span class="progressTrigger">Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="50623864" data-restore-rating="null" data-submit-url="/review/rate/50623864?stars_click=true&amp;wtr_button_id=1_book_50623864" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">2</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="45047384"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="45047384" data-resource-type="Book">
# <a href="/book/show/45047384-the-house-in-the-cerulean-sea" title="The House in the Cerulean Sea">
# <img alt="The House in the Cerulean S..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1569514209i/45047384._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/45047384-the-house-in-the-cerulean-sea" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">The House in the Cerulean Sea (Cerulean Chronicles, #1)</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/5073330.T_J_Klune" itemprop="url"><span itemprop="name">T.J. Klune</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.40 avg rating — 711,792 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 45,759</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_26502" onclick="new Ajax.Request('/list/list_book/10272142', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_26502');$('loading_link_26502').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_26502').show();;Element.hide('loading_anim_26502');}, onLoading:function(request){;Element.show('loading_anim_26502');Element.hide('loading_link_26502')}, onSuccess:function(request){Element.hide('loading_anim_26502');Element.show('loading_link_26502');}, parameters:'authenticity_token=' + encodeURIComponent('b7oF4SFX1yvDTb4BINQTu9Wf/ONBgCMZtwaBKu8xpngGO0VQgI64HtgMk+8T25iEFgxyBvAwOTtj31MEYZNkAw==')}); return false;">464 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_26502" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="2_book_45047384">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="CeCM7YczgKxJHBDgpobeVtnO7hdCGdbOP6VbOguiqMZgYcxcJurvmVJdPQ6ViVVpGl1g8vOpzOzrfIkUhQBqvQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="45047384"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_45047384"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="aXmVR3d+z9zoxHGp+WNCbSON7dDnP6/HsrqdZd/M+aoA+NX21qeg6fOFXEfKbMlS4B5jNVaPteVmY09LUW470Q=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_45047384"/>
# <input id="book_id" name="book_id" type="hidden" value="45047384"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="45047384" data-restore-rating="null" data-submit-url="/review/rate/45047384?stars_click=true&amp;wtr_button_id=2_book_45047384" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">3</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="54493401"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="54493401" data-resource-type="Book">
# <a href="/book/show/54493401-project-hail-mary" title="Project Hail Mary">
# <img alt="Project Hail Mary" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1597695864i/54493401._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/54493401-project-hail-mary" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Project Hail Mary</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/6540057.Andy_Weir" itemprop="url"><span itemprop="name">Andy Weir</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p6" size="12x12"></span></span> 4.51 avg rating — 652,030 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 44,780</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_112626" onclick="new Ajax.Request('/list/list_book/10955124', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_112626');$('loading_link_112626').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_112626').show();;Element.hide('loading_anim_112626');}, onLoading:function(request){;Element.show('loading_anim_112626');Element.hide('loading_link_112626')}, onSuccess:function(request){Element.hide('loading_anim_112626');Element.show('loading_link_112626');}, parameters:'authenticity_token=' + encodeURIComponent('jJtlxvCgHokUajwINctM9jIqiHLQrHPTvi3ZtyohOdnlGiV3UXlxvA8rEeYGxMfJ8bkGl2EcafFq9AuZpIP7og==')}); return false;">456 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_112626" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="3_book_54493401">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="R1hDmPQtAz5AeoWncF1dPLe83QRVJUQAab/qtPN6FuMu2QMpVfRsC1s7qElDUtYDdC9T4eSVXiK9ZjiafdjUmA=="/>
# <input id="book_id" name="book_id" type="hidden" value="54493401"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_54493401"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="kFQw0+60zlye5u5zeh5eGUePH5vWn1ICSAfU6nAeF3/51XBiT22haYWnw51JEdUmhByRfmcvSCCc3gbE/rzVBA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_54493401"/>
# <input id="book_id" name="book_id" type="hidden" value="54493401"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="54493401" data-restore-rating="null" data-submit-url="/review/rate/54493401?stars_click=true&amp;wtr_button_id=3_book_54493401" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">4</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="52578297"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="52578297" data-resource-type="Book">
# <a href="/book/show/52578297-the-midnight-library" title="The Midnight Library">
# <img alt="The Midnight Library" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1602190253i/52578297._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/52578297-the-midnight-library" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">The Midnight Library</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/76360.Matt_Haig" itemprop="url"><span itemprop="name">Matt Haig</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p6" size="12x12"></span><span class="staticStar p0" size="12x12"></span></span> 3.99 avg rating — 1,955,059 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 41,857</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_428161" onclick="new Ajax.Request('/list/list_book/11025263', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_428161');$('loading_link_428161').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_428161').show();;Element.hide('loading_anim_428161');}, onLoading:function(request){;Element.show('loading_anim_428161');Element.hide('loading_link_428161')}, onSuccess:function(request){Element.hide('loading_anim_428161');Element.show('loading_link_428161');}, parameters:'authenticity_token=' + encodeURIComponent('mznbx6I6apAsmeYUO8eCZaooxztIjmgMReilBHJw5xnyuJt2A+MFpTfYy/oIyAlaabtJ3vk+ci6RMXcq/NIlYg==')}); return false;">427 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_428161" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="4_book_52578297">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ClKQ9OqmsSKJpepmFqejRUJ0reY0wp+pkXUPM6osn5lj09BFS3/eF5Lkx4glqCh6gecjA4VyhYtFrN0dJI5d4g=="/>
# <input id="book_id" name="book_id" type="hidden" value="52578297"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_52578297"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Ni/EIHEv7QfI26kQ1qeepscv2sjiuNDXiSlMEtrT1kRfroSR0PaCMtOahP7lqBWZBLxULVMIyvVd8J48VHEUPw=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_52578297"/>
# <input id="book_id" name="book_id" type="hidden" value="52578297"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="52578297" data-restore-rating="null" data-submit-url="/review/rate/52578297?stars_click=true&amp;wtr_button_id=4_book_52578297" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">5</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="59364173"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="59364173" data-resource-type="Book">
# <a href="/book/show/59364173-i-m-glad-my-mom-died" title="I'm Glad My Mom Died">
# <img alt="I'm Glad My Mom Died" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1649286799i/59364173._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/59364173-i-m-glad-my-mom-died" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">I'm Glad My Mom Died</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/15457334.Jennette_McCurdy" itemprop="url"><span itemprop="name">Jennette McCurdy</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.46 avg rating — 1,144,921 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 35,328</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_680269" onclick="new Ajax.Request('/list/list_book/12772618', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_680269');$('loading_link_680269').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_680269').show();;Element.hide('loading_anim_680269');}, onLoading:function(request){;Element.show('loading_anim_680269');Element.hide('loading_link_680269')}, onSuccess:function(request){Element.hide('loading_anim_680269');Element.show('loading_link_680269');}, parameters:'authenticity_token=' + encodeURIComponent('DVd6ZO5FrMqNRlvn8/U+Q1ysYUNrPy/lvOQPpE7NhD9k1jrVT5zD/5YHdgnA+rV8nz/vptqPNcdoPd2KwG9GRA==')}); return false;">361 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_680269" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="5_book_59364173">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="fU14z9KdzdxL2OpV18IuWxtOGP3m6f/JO2bfUAjHJ7AUzDh+c0Si6VCZx7vkzaVk2N2WGFdZ5evvvw1+hmXlyw=="/>
# <input id="book_id" name="book_id" type="hidden" value="59364173"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_59364173"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="7Ii0R7NocuqzxepTyUOEsTz19L21dkgHjxpviuS4F6SFCfT2ErEd36iEx736TA+O/2Z6WATGUiVbw72kahrV3w=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_59364173"/>
# <input id="book_id" name="book_id" type="hidden" value="59364173"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="59364173" data-restore-rating="null" data-submit-url="/review/rate/59364173?stars_click=true&amp;wtr_button_id=5_book_59364173" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">6</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="61431922"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="61431922" data-resource-type="Book">
# <a href="/book/show/61431922-fourth-wing" title="Fourth Wing">
# <img alt="Fourth Wing (The Empyrean, #1)" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1701980900i/61431922._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/61431922-fourth-wing" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Fourth Wing (The Empyrean, #1)</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/7539785.Rebecca_Yarros" itemprop="url"><span itemprop="name">Rebecca Yarros</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p6" size="12x12"></span></span> 4.57 avg rating — 2,038,598 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 30,801</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_376636" onclick="new Ajax.Request('/list/list_book/13020297', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_376636');$('loading_link_376636').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_376636').show();;Element.hide('loading_anim_376636');}, onLoading:function(request){;Element.show('loading_anim_376636');Element.hide('loading_link_376636')}, onSuccess:function(request){Element.hide('loading_anim_376636');Element.show('loading_link_376636');}, parameters:'authenticity_token=' + encodeURIComponent('eHQgkqK8QCVKC5Ki8o1eYonnYvK74fCA/9lO90Q2z78R9WAjA2UvEFFKv0zBgtVdSnTsFwpR6qIrAJzZypQNxA==')}); return false;">315 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_376636" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="6_book_61431922">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="jlkpTNZlJHmlk+pWhB20aEIRI0frF8dwtIuytltP9YTn2Gn9d7xLTL7Sx7i3Ej9XgYKtolqn3VJgUmCY1e03/w=="/>
# <input id="book_id" name="book_id" type="hidden" value="61431922"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="6_book_61431922"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="61vZPTs5KW40V3GwvqrMZVBcjKXgQg7ykxPSScVwe+yC2pmMmuBGWy8WXF6NpUdak88CQFHyFNBHygBnS9K5lw=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="6_book_61431922"/>
# <input id="book_id" name="book_id" type="hidden" value="61431922"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="61431922" data-restore-rating="null" data-submit-url="/review/rate/61431922?stars_click=true&amp;wtr_button_id=6_book_61431922" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">7</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="51901147"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="51901147" data-resource-type="Book">
# <a href="/book/show/51901147-the-ballad-of-songbirds-and-snakes" title="The Ballad of Songbirds and Snakes">
# <img alt="The Ballad of Songbirds and..." class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1593892032i/51901147._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/51901147-the-ballad-of-songbirds-and-snakes" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">The Ballad of Songbirds and Snakes (The Hunger Games, #0)</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/153394.Suzanne_Collins" itemprop="url"><span itemprop="name">Suzanne Collins</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p6" size="12x12"></span><span class="staticStar p0" size="12x12"></span></span> 3.96 avg rating — 848,906 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 23,463</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_29049" onclick="new Ajax.Request('/list/list_book/9965640', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_29049');$('loading_link_29049').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_29049').show();;Element.hide('loading_anim_29049');}, onLoading:function(request){;Element.show('loading_anim_29049');Element.hide('loading_link_29049')}, onSuccess:function(request){Element.hide('loading_anim_29049');Element.show('loading_link_29049');}, parameters:'authenticity_token=' + encodeURIComponent('pWz08ghxezQCAqn53xODB53pS4YSXd0XTVivf+IZe73M7bRDqagUARlDhBfsHAg4XnrFY6PtxzWZgX1RbLu5xg==')}); return false;">239 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_29049" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="7_book_51901147">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="y58aMbA0PSwA0vCZ0TWcogkiKMKIqxUUSQH8LZ15j9+iHlqAEe1SGRuT3XfiOhedyrGmJzkbDzad2C4DE9tNpA=="/>
# <input id="book_id" name="book_id" type="hidden" value="51901147"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="7_book_51901147"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ePr5gnsMZkXWgveZFyMUYmJ7bxn3uZQrcsKN3gAv2HkRe7kz2tUJcM3D2nckLJ9doejh/EYJjgmmG1/wjo0aAg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="7_book_51901147"/>
# <input id="book_id" name="book_id" type="hidden" value="51901147"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="51901147" data-restore-rating="null" data-submit-url="/review/rate/51901147?stars_click=true&amp;wtr_button_id=7_book_51901147" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">8</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="50202953"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="50202953" data-resource-type="Book">
# <a href="/book/show/50202953-piranesi" title="Piranesi">
# <img alt="Piranesi" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1609095173i/50202953._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/50202953-piranesi" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Piranesi</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/8842.Susanna_Clarke" itemprop="url"><span itemprop="name">Susanna Clarke</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.23 avg rating — 320,700 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 22,748</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_155170" onclick="new Ajax.Request('/list/list_book/10302560', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_155170');$('loading_link_155170').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_155170').show();;Element.hide('loading_anim_155170');}, onLoading:function(request){;Element.show('loading_anim_155170');Element.hide('loading_link_155170')}, onSuccess:function(request){Element.hide('loading_anim_155170');Element.show('loading_link_155170');}, parameters:'authenticity_token=' + encodeURIComponent('99LJOrgP1HAPL4/P7NbJ9yGGX2NFrf9YLZ6SaWQ9vUCeU4mLGda7RRRuoiHf2ULI4hXRhvQd5Xr5R0BH6p9/Ow==')}); return false;">231 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_155170" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="8_book_50202953">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Cybu589uQ3Rt/cOpeuyd8opvqTw/Y1oPCut195su1Vdip65WbrcsQXa87kdJ4xbNSfwn2Y7TQC3eMqfZFYwXLA=="/>
# <input id="book_id" name="book_id" type="hidden" value="50202953"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="8_book_50202953"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="MvkhYHPLdQcWHfx4j4vrKAed9BrTaX4AWyRh/UHNCRdbeGHR0hIaMg1c0Za8hGAXxA56/2LZZCKP/bPTz2/LbA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="8_book_50202953"/>
# <input id="book_id" name="book_id" type="hidden" value="50202953"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="50202953" data-restore-rating="null" data-submit-url="/review/rate/50202953?stars_click=true&amp;wtr_button_id=8_book_50202953" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">9</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="58065033"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="58065033" data-resource-type="Book">
# <a href="/book/show/58065033-lessons-in-chemistry" title="Lessons in Chemistry">
# <img alt="Lessons in Chemistry" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1634748496i/58065033._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/58065033-lessons-in-chemistry" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Lessons in Chemistry</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/21370624.Bonnie_Garmus" itemprop="url"><span itemprop="name">Bonnie Garmus</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.29 avg rating — 1,434,499 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 22,246</a>,
#               <span class="greyText">and</span>
# ...
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/7367300.T_Kingfisher" itemprop="url"><span itemprop="name">T. Kingfisher</span></a>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p6" size="12x12"></span><span class="staticStar p0" size="12x12"></span></span> 3.80 avg rating — 39,280 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 2,209</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_797127" onclick="new Ajax.Request('/list/list_book/9798111', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_797127');$('loading_link_797127').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_797127').show();;Element.hide('loading_anim_797127');}, onLoading:function(request){;Element.show('loading_anim_797127');Element.hide('loading_link_797127')}, onSuccess:function(request){Element.hide('loading_anim_797127');Element.show('loading_link_797127');}, parameters:'authenticity_token=' + encodeURIComponent('j5RA0qjcSUXav79yLcA+IE7lzfjlOoiDb+5hpscETxbmFQBjCQUmcMH+kpwez7UfjXZDHVSKkqG7N7OISaaNbQ==')}); return false;">24 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_797127" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="98_book_50897175">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="dRC4VjvLOkSYV4mMEgKa15ohRl9dpzx7Z15Kf1SqkwgckfjnmhJVcYMWpGIhDRHoWbLIuuwXJlmzh5hR2ghRcw=="/>
# <input id="book_id" name="book_id" type="hidden" value="50897175"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="98_book_50897175"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="HKyH4n0Y8lCYsS8jrVso9jcCcoOp1KBGCAtpfvRLFRl1LcdT3MGdZYPwAs2eVKPJ9JH8ZhhkumTc0rtQeunXYg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="98_book_50897175"/>
# <input id="book_id" name="book_id" type="hidden" value="50897175"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="50897175" data-restore-rating="null" data-submit-url="/review/rate/50897175?stars_click=true&amp;wtr_button_id=98_book_50897175" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">99</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="45134200"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="45134200" data-resource-type="Book">
# <a href="/book/show/45134200-the-switch" title="The Switch">
# <img alt="The Switch" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1573576865i/45134200._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/45134200-the-switch" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">The Switch</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/13038484.Beth_O_Leary" itemprop="url"><span itemprop="name">Beth O'Leary</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p6" size="12x12"></span><span class="staticStar p0" size="12x12"></span></span> 3.95 avg rating — 134,320 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 2,192</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_888866" onclick="new Ajax.Request('/list/list_book/9697985', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_888866');$('loading_link_888866').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_888866').show();;Element.hide('loading_anim_888866');}, onLoading:function(request){;Element.show('loading_anim_888866');Element.hide('loading_link_888866')}, onSuccess:function(request){Element.hide('loading_anim_888866');Element.show('loading_link_888866');}, parameters:'authenticity_token=' + encodeURIComponent('QhT+k37f7dJESNlnsrAx5lryniT6TrL+fO2KpwA+HMErlb4i3waC518J9ImBv7rZmWEQwUv+qNyoNFiJjpzeug==')}); return false;">24 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_888866" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="99_book_45134200">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ggG68BTfa8Id02mor6VcVxp3QnWOD6M3vgztLCsV5VDrgPpBtQYE9waSREacqtdo2eTMkD+/uRVq1T8CpbcnKw=="/>
# <input id="book_id" name="book_id" type="hidden" value="45134200"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="99_book_45134200"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="eEn+kgIFY7kFgVpgSrLy8LFSjBFSgXN+2swr2uMjOqwRyL4jo9wMjB7Ad455vXnPcsEC9OMxaVwOFfn0bYH41w=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="99_book_45134200"/>
# <input id="book_id" name="book_id" type="hidden" value="45134200"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="45134200" data-restore-rating="null" data-submit-url="/review/rate/45134200?stars_click=true&amp;wtr_button_id=99_book_45134200" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# <!-- Add query string params -->
# <tr itemscope="" itemtype="http://schema.org/Book">
# <td class="number" valign="top">100</td>
# <td valign="top" width="5%">
# <div class="u-anchorTarget" id="42121525"></div>
# <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="42121525" data-resource-type="Book">
# <a href="/book/show/42121525-migrations" title="Migrations">
# <img alt="Migrations" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1612818084i/42121525._SY75_.jpg"/>
# </a> </div>
# </td>
# <td valign="top" width="100%">
# <a class="bookTitle" href="/book/show/42121525-migrations" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Migrations</span>
# </a> <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/2869149.Charlotte_McConaghy" itemprop="url"><span itemprop="name">Charlotte McConaghy</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
# <br/>
# <div>
# <span class="greyText smallText uitext">
# <span class="minirating"><span class="stars staticStars notranslate"><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p10" size="12x12"></span><span class="staticStar p3" size="12x12"></span></span> 4.13 avg rating — 79,386 ratings</span>
# </span>
# </div>
# <div style="margin-top: 5px">
# <span class="smallText uitext">
# <a href="#" onclick="Lightbox.showBoxByID('score_explanation', 300); return false;">score: 2,120</a>,
#               <span class="greyText">and</span>
# <a href="#" id="loading_link_12179" onclick="new Ajax.Request('/list/list_book/9993919', {asynchronous:true, evalScripts:true, onFailure:function(request){Element.hide('loading_anim_12179');$('loading_link_12179').innerHTML = '&lt;span class=&quot;error&quot;&gt;ERROR&lt;/span&gt;try again';$('loading_link_12179').show();;Element.hide('loading_anim_12179');}, onLoading:function(request){;Element.show('loading_anim_12179');Element.hide('loading_link_12179')}, onSuccess:function(request){Element.hide('loading_anim_12179');Element.show('loading_link_12179');}, parameters:'authenticity_token=' + encodeURIComponent('mYKdiUpnhjGS5i23stiP60X7qbhXYsuGfwJlYwYv7IrwA904677pBImnAFmB1wTUhmgnXebS0aSr27dNiI0u8Q==')}); return false;">23 people voted</a><img alt="Loading trans" class="loading" id="loading_anim_12179" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif" style="display:none"/>
#
#
#             </span>
# </div>
# </td>
# <td width="130px">
# <div class="wtrButtonContainer wtrSignedOut" id="100_book_42121525">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="bB4G5XleRxDth408xMadx3UEHMsZLp60u5Ccc9iwBKcFn0ZU2IcoJfbGoNL3yRb4tpeSLqiehJZvSU5dVhLG3A=="/>
# <input id="book_id" name="book_id" type="hidden" value="42121525"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="100_book_42121525"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="UEdA4uECJUSuYSrrek6hCnZIUV7oTYHEa6iIApoSK3M5xgBTQNtKcbUgBwVJQSo1tdvfu1n9m+a/cVosFLDpCA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="100_book_42121525"/>
# <input id="book_id" name="book_id" type="hidden" value="42121525"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="42121525" data-restore-rating="null" data-submit-url="/review/rate/42121525?stars_click=true&amp;wtr_button_id=100_book_42121525" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </td>
# </tr>
# </table>

# %% [markdown]
# #### Extracting the book titles from the table

# %%
titles = main_table.find_all('a', class_='bookTitle')
book_titles = [title.text.strip() for title in titles]
book_titles
# Out:
# ['The Invisible Life of Addie LaRue',
#  'The House in the Cerulean Sea (Cerulean Chronicles, #1)',
#  'Project Hail Mary',
#  'The Midnight Library',
#  "I'm Glad My Mom Died",
#  'Fourth Wing (The Empyrean, #1)',
#  'The Ballad of Songbirds and Snakes (The Hunger Games, #0)',
#  'Piranesi',
#  'Lessons in Chemistry',
#  'House of Earth and Blood (Crescent City, #1)',
#  'Tomorrow, and Tomorrow, and Tomorrow',
#  'My Dark Vanessa',
#  'The Vanishing Half',
#  'A \u200bCourt of Silver Flames (A Court of Thorns and Roses, #4)',
#  'Beach Read',
#  'The Love Hypothesis',
#  'Babel',
#  'Malibu Rising',
#  'The Inheritance Games (The Inheritance Games, #1)',
#  'Book Lovers',
#  'The Four Winds',
#  'Under the Whispering Door',
#  'Remarkably Bright Creatures',
#  'American Dirt',
#  'Crying in H Mart',
#  'Mexican Gothic',
#  'Heartstopper: Volume Three (Heartstopper, #3)',
#  'Carrie Soto Is Back',
#  'The Thursday Murder Club (Thursday Murder Club, #1)',
#  'Sea of Tranquility',
#  'Hamnet',
#  'The Guest List',
#  'House of Sky and Breath (Crescent City, #2)',
#  'A Deadly Education (The Scholomance, #1)',
#  'Divine Rivals (Letters of Enchantment, #1)',
#  'Klara and the Sun',
#  'Caste: The Origins of Our Discontents',
#  'Bell Hammers',
#  'People We Meet on Vacation',
#  'Loveless',
#  'Demon Copperhead',
#  'From Blood and Ash (Blood and Ash, #1)',
#  'Network Effect (The Murderbot Diaries, #5)',
#  'Iron Flame (The Empyrean, #2)',
#  'One of Us Is Next (One of Us Is Lying, #2)',
#  'Heartstopper: Volume Four (Heartstopper, #4)',
#  'Legendborn (The Legendborn Cycle, #1)',
#  'Chain of Gold (The Last Hours, #1)',
#  'Cloud Cuckoo Land',
#  'A Psalm for the Wild-Built (Monk & Robot, #1)',
#  'The Glass Hotel',
#  'Rhythm of War (The Stormlight Archive, #4)',
#  'The Burning God (The Poppy War, #3)',
#  'Rule of Wolves (King of Scars, #2)',
#  'The Maid (Molly the Maid, #1)',
#  'Transcendent Kingdom',
#  'These Violent Delights (These Violent Delights, #1)',
#  'Shuggie Bain',
#  'Untamed',
#  'A Promised Land',
#  'Hood Feminism: Notes from the Women That a Movement Forgot',
#  'Greenlights',
#  'The Rose Code',
#  "Good Girl, Bad Blood (A Good Girl's Guide to Murder, #2)",
#  'Cemetery Boys (Cemetery Boys, #1)',
#  'The Anthropocene Reviewed: Essays on a Human-Centered Planet',
#  'Firekeeper’s Daughter',
#  'Writers & Lovers',
#  'Yellowface',
#  'The Splendid and the Vile: A Saga of Churchill, Family, and Defiance During the Blitz',
#  'The Sun Down Motel',
#  'Tress of the Emerald Sea',
#  'Ring Shout',
#  'The Spanish Love Deception (Spanish Love Deception, #1)',
#  'Felix Ever After',
#  'The Book of Longings',
#  'The Girl with the Louding Voice',
#  'Long Bright River',
#  'Take a Hint, Dani Brown (The Brown Sisters, #2)',
#  'The Henna Artist (The Jaipur Trilogy, #1)',
#  'The Empire of Gold (The Daevabad Trilogy, #3)',
#  'The Push',
#  'The Mirror & the Light (Thomas Cromwell, #3)',
#  'A Kingdom of Flesh and Fire (Blood and Ash, #2)',
#  'Billy Summers',
#  'The City We Became (Great Cities, #1)',
#  'The Guncle (The Guncle, #1)',
#  'Dear Edward',
#  'Happy Place',
#  'The Book of Lost Names',
#  'Clap When You Land',
#  'One to Watch',
#  'Home Before Dark',
#  'The Dictionary of Lost Words',
#  'Legends & Lattes (Legends & Lattes, #1)',
#  'Oona Out of Order',
#  'The Death of Vivek Oji',
#  'The Hollow Places',
#  'The Switch',
#  'Migrations']

# %% [markdown]
# #### Extracting the authors' names

# %%
authors = main_table.find_all('a', class_ = 'authorName')
book_authors = [author.text.strip() for author in authors]
book_authors
# Out:
# ['Victoria Schwab',
#  'T.J. Klune',
#  'Andy Weir',
#  'Matt Haig',
#  'Jennette McCurdy',
#  'Rebecca Yarros',
#  'Suzanne Collins',
#  'Susanna Clarke',
#  'Bonnie Garmus',
#  'Sarah J. Maas',
#  'Gabrielle Zevin',
#  'Kate Elizabeth Russell',
#  'Brit Bennett',
#  'Sarah J. Maas',
#  'Emily Henry',
#  'Ali Hazelwood',
#  'R.F. Kuang',
#  'Taylor Jenkins Reid',
#  'Jennifer Lynn Barnes',
#  'Emily Henry',
#  'Kristin Hannah',
#  'T.J. Klune',
#  'Shelby Van Pelt',
#  'Jeanine Cummins',
#  'Michelle Zauner',
#  'Silvia Moreno-Garcia',
#  'Alice Oseman',
#  'Taylor Jenkins Reid',
#  'Richard Osman',
#  'Emily St. John Mandel',
#  "Maggie O'Farrell",
#  'Lucy Foley',
#  'Sarah J. Maas',
#  'Naomi Novik',
#  'Rebecca   Ross',
#  'Kazuo Ishiguro',
#  'Isabel Wilkerson',
#  'Lancelot Schaubert',
#  'Emily Henry',
#  'Alice Oseman',
#  'Barbara Kingsolver',
#  'Jennifer L. Armentrout',
#  'Martha Wells',
#  'Rebecca Yarros',
#  'Karen M. McManus',
#  'Alice Oseman',
#  'Tracy Deonn',
#  'Cassandra Clare',
#  'Anthony Doerr',
#  'Becky  Chambers',
#  'Emily St. John Mandel',
#  'Brandon Sanderson',
#  'R.F. Kuang',
#  'Leigh Bardugo',
#  'Nita Prose',
#  'Yaa Gyasi',
#  'Chloe Gong',
#  'Douglas   Stuart',
#  'Glennon Doyle',
#  'Barack Obama',
#  'Mikki Kendall',
#  'Matthew McConaughey',
#  'Kate Quinn',
#  'Holly  Jackson',
#  'Aiden Thomas',
#  'John Green',
#  'Angeline Boulley',
#  'Lily King',
#  'R.F. Kuang',
#  'Erik Larson',
#  'Simone St. James',
#  'Brandon Sanderson',
#  'P. Djèlí Clark',
#  'Elena  Armas',
#  'Kacen Callender',
#  'Sue Monk Kidd',
#  'Abi Daré',
#  'Liz    Moore',
#  'Talia Hibbert',
#  'Alka Joshi',
#  'S.A. Chakraborty',
#  'Ashley Audrain',
#  'Hilary Mantel',
#  'Jennifer L. Armentrout',
#  'Stephen         King',
#  'N.K. Jemisin',
#  'Steven  Rowley',
#  'Ann Napolitano',
#  'Emily Henry',
#  'Kristin Harmel',
#  'Elizabeth Acevedo',
#  'Kate Stayman-London',
#  'Riley Sager',
#  'Pip Williams',
#  'Travis Baldree',
#  'Margarita Montimore',
#  'Akwaeke Emezi',
#  'T. Kingfisher',
#  "Beth O'Leary",
#  'Charlotte McConaghy']

# %% [markdown]
# #### Extracting the books' ratings

# %%
ratings = main_table.find_all('span', class_ = 'minirating')
book_ratings = [rating.text.strip() for rating in ratings]
book_ratings
# Out:
# ['4.18 avg rating — 1,176,362 ratings',
#  '4.40 avg rating — 711,792 ratings',
#  '4.51 avg rating — 652,030 ratings',
#  '3.99 avg rating — 1,955,059 ratings',
#  '4.46 avg rating — 1,144,921 ratings',
#  '4.57 avg rating — 2,038,598 ratings',
#  '3.96 avg rating — 848,906 ratings',
#  '4.23 avg rating — 320,700 ratings',
#  '4.29 avg rating — 1,434,499 ratings',
#  '4.47 avg rating — 806,921 ratings',
#  '4.15 avg rating — 1,027,167 ratings',
#  '4.10 avg rating — 358,308 ratings',
#  '4.14 avg rating — 784,507 ratings',
#  '4.47 avg rating — 1,419,734 ratings',
#  'really liked it 4.00 avg rating — 1,295,486 ratings',
#  '4.13 avg rating — 1,506,796 ratings',
#  '4.18 avg rating — 279,260 ratings',
#  '4.03 avg rating — 1,114,505 ratings',
#  '4.15 avg rating — 824,243 ratings',
#  '4.13 avg rating — 1,218,968 ratings',
#  '4.30 avg rating — 747,721 ratings',
#  '4.15 avg rating — 254,206 ratings',
#  '4.39 avg rating — 736,195 ratings',
#  '4.37 avg rating — 604,715 ratings',
#  '4.26 avg rating — 469,819 ratings',
#  '3.67 avg rating — 379,268 ratings',
#  '4.56 avg rating — 455,753 ratings',
#  '4.21 avg rating — 579,159 ratings',
#  '3.88 avg rating — 548,980 ratings',
#  '4.07 avg rating — 254,308 ratings',
#  '4.20 avg rating — 277,009 ratings',
#  '3.81 avg rating — 1,086,488 ratings',
#  '4.47 avg rating — 563,696 ratings',
#  '3.96 avg rating — 184,968 ratings',
#  '4.19 avg rating — 514,609 ratings',
#  '3.74 avg rating — 364,802 ratings',
#  '4.53 avg rating — 145,081 ratings',
#  '4.16 avg rating — 657 ratings',
#  '3.86 avg rating — 1,286,882 ratings',
#  '4.20 avg rating — 108,390 ratings',
#  '4.50 avg rating — 514,530 ratings',
#  '4.23 avg rating — 646,864 ratings',
#  '4.47 avg rating — 93,974 ratings',
#  '4.35 avg rating — 1,358,141 ratings',
#  '3.91 avg rating — 246,405 ratings',
#  '4.60 avg rating — 401,671 ratings',
#  '4.33 avg rating — 148,525 ratings',
#  '4.38 avg rating — 110,209 ratings',
#  '4.26 avg rating — 231,083 ratings',
#  '4.27 avg rating — 128,585 ratings',
#  '3.69 avg rating — 179,848 ratings',
#  '4.62 avg rating — 165,199 ratings',
#  '4.30 avg rating — 104,391 ratings',
#  '4.35 avg rating — 158,021 ratings',
#  '3.76 avg rating — 598,445 ratings',
#  '4.11 avg rating — 152,076 ratings',
#  '3.83 avg rating — 153,532 ratings',
#  '4.31 avg rating — 162,928 ratings',
#  '3.99 avg rating — 463,882 ratings',
#  '4.33 avg rating — 240,370 ratings',
#  '4.37 avg rating — 54,764 ratings',
#  '4.21 avg rating — 360,850 ratings',
#  '4.45 avg rating — 283,779 ratings',
#  '4.29 avg rating — 586,580 ratings',
#  '4.27 avg rating — 96,991 ratings',
#  '4.36 avg rating — 137,802 ratings',
#  '4.33 avg rating — 169,881 ratings',
#  '4.01 avg rating — 150,504 ratings',
#  '3.76 avg rating — 630,131 ratings',
#  '4.30 avg rating — 122,304 ratings',
#  '4.01 avg rating — 160,803 ratings',
#  '4.39 avg rating — 163,953 ratings',
#  '3.99 avg rating — 38,048 ratings',
#  '3.82 avg rating — 729,012 ratings',
#  '4.24 avg rating — 63,312 ratings',
#  '4.23 avg rating — 129,227 ratings',
#  '4.43 avg rating — 156,764 ratings',
#  '4.04 avg rating — 117,990 ratings',
#  '4.01 avg rating — 103,453 ratings',
#  '4.19 avg rating — 188,732 ratings',
#  '4.50 avg rating — 61,197 ratings',
#  '4.05 avg rating — 369,477 ratings',
#  '4.39 avg rating — 40,965 ratings',
#  '4.34 avg rating — 452,723 ratings',
#  '4.20 avg rating — 166,597 ratings',
#  '3.86 avg rating — 72,885 ratings',
#  '4.13 avg rating — 157,593 ratings',
#  '4.08 avg rating — 192,565 ratings',
#  '3.98 avg rating — 1,060,370 ratings',
#  '4.43 avg rating — 224,168 ratings',
#  '4.24 avg rating — 104,024 ratings',
#  '3.88 avg rating — 94,992 ratings',
#  '4.07 avg rating — 219,777 ratings',
#  '4.02 avg rating — 155,850 ratings',
#  '4.11 avg rating — 227,577 ratings',
#  '3.86 avg rating — 86,798 ratings',
#  '4.13 avg rating — 62,571 ratings',
#  '3.80 avg rating — 39,280 ratings',
#  '3.95 avg rating — 134,320 ratings',
#  '4.13 avg rating — 79,386 ratings']

# %%
df = pd.DataFrame(columns=['Title', 'Author', 'Avg. Rating'])
df
# Out:
# Empty DataFrame
# Columns: [Title, Author, Avg. Rating]
# Index: []

# %%
length = len(book_authors)
length
# Out:
# 100

# %% [markdown]
# #### Putting the extracted data into a DataFrame

# %%
df['Title'] = book_titles
df['Author'] = book_authors
df['Avg. Rating'] = book_ratings
df
# Out:
#                                                 Title               Author  \
# 0                   The Invisible Life of Addie LaRue      Victoria Schwab
# 1   The House in the Cerulean Sea (Cerulean Chroni...           T.J. Klune
# 2                                   Project Hail Mary            Andy Weir
# 3                                The Midnight Library            Matt Haig
# 4                                I'm Glad My Mom Died     Jennette McCurdy
# ..                                                ...                  ...
# 95                                  Oona Out of Order  Margarita Montimore
# 96                             The Death of Vivek Oji        Akwaeke Emezi
# 97                                  The Hollow Places        T. Kingfisher
# 98                                         The Switch         Beth O'Leary
# 99                                         Migrations  Charlotte McConaghy
#
#                             Avg. Rating
# 0   4.18 avg rating — 1,176,362 ratings
# 1     4.40 avg rating — 711,792 ratings
# 2     4.51 avg rating — 652,030 ratings
# 3   3.99 avg rating — 1,955,059 ratings
# 4   4.46 avg rating — 1,144,921 ratings
# ..                                  ...
# 95     3.86 avg rating — 86,798 ratings
# 96     4.13 avg rating — 62,571 ratings
# 97     3.80 avg rating — 39,280 ratings
# 98    3.95 avg rating — 134,320 ratings
# 99     4.13 avg rating — 79,386 ratings
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Splitting the 'Avg. Rating' column into 'Avg. Rating' and 'No. of Reviews' columns

# %%
df[['Avg. Rating', 'No. of Reviews']] = df['Avg. Rating'].str.split('—', expand=True)
df
# Out:
#                                                 Title               Author  \
# 0                   The Invisible Life of Addie LaRue      Victoria Schwab
# 1   The House in the Cerulean Sea (Cerulean Chroni...           T.J. Klune
# 2                                   Project Hail Mary            Andy Weir
# 3                                The Midnight Library            Matt Haig
# 4                                I'm Glad My Mom Died     Jennette McCurdy
# ..                                                ...                  ...
# 95                                  Oona Out of Order  Margarita Montimore
# 96                             The Death of Vivek Oji        Akwaeke Emezi
# 97                                  The Hollow Places        T. Kingfisher
# 98                                         The Switch         Beth O'Leary
# 99                                         Migrations  Charlotte McConaghy
#
#          Avg. Rating      No. of Reviews
# 0   4.18 avg rating    1,176,362 ratings
# 1   4.40 avg rating      711,792 ratings
# 2   4.51 avg rating      652,030 ratings
# 3   3.99 avg rating    1,955,059 ratings
# 4   4.46 avg rating    1,144,921 ratings
# ..               ...                 ...
# 95  3.86 avg rating       86,798 ratings
# 96  4.13 avg rating       62,571 ratings
# 97  3.80 avg rating       39,280 ratings
# 98  3.95 avg rating      134,320 ratings
# 99  4.13 avg rating       79,386 ratings
#
# [100 rows x 4 columns]

# %% [markdown]
# #### Cleaning and Correcting the 'Avg. Rating' column

# %%
df['Avg. Rating'] = df['Avg. Rating'].str.replace("[^0-9]", "", regex=True)
df['Avg. Rating'] = df['Avg. Rating'].apply(lambda x: float(x))
df
# Out:
#                                                 Title               Author  \
# 0                   The Invisible Life of Addie LaRue      Victoria Schwab
# 1   The House in the Cerulean Sea (Cerulean Chroni...           T.J. Klune
# 2                                   Project Hail Mary            Andy Weir
# 3                                The Midnight Library            Matt Haig
# 4                                I'm Glad My Mom Died     Jennette McCurdy
# ..                                                ...                  ...
# 95                                  Oona Out of Order  Margarita Montimore
# 96                             The Death of Vivek Oji        Akwaeke Emezi
# 97                                  The Hollow Places        T. Kingfisher
# 98                                         The Switch         Beth O'Leary
# 99                                         Migrations  Charlotte McConaghy
#
#     Avg. Rating      No. of Reviews
# 0         418.0   1,176,362 ratings
# 1         440.0     711,792 ratings
# 2         451.0     652,030 ratings
# 3         399.0   1,955,059 ratings
# 4         446.0   1,144,921 ratings
# ..          ...                 ...
# 95        386.0      86,798 ratings
# 96        413.0      62,571 ratings
# 97        380.0      39,280 ratings
# 98        395.0     134,320 ratings
# 99        413.0      79,386 ratings
#
# [100 rows x 4 columns]

# %%
df['Avg. Rating'] = df['Avg. Rating']/100
df
# Out:
#                                                 Title               Author  \
# 0                   The Invisible Life of Addie LaRue      Victoria Schwab
# 1   The House in the Cerulean Sea (Cerulean Chroni...           T.J. Klune
# 2                                   Project Hail Mary            Andy Weir
# 3                                The Midnight Library            Matt Haig
# 4                                I'm Glad My Mom Died     Jennette McCurdy
# ..                                                ...                  ...
# 95                                  Oona Out of Order  Margarita Montimore
# 96                             The Death of Vivek Oji        Akwaeke Emezi
# 97                                  The Hollow Places        T. Kingfisher
# 98                                         The Switch         Beth O'Leary
# 99                                         Migrations  Charlotte McConaghy
#
#     Avg. Rating      No. of Reviews
# 0          4.18   1,176,362 ratings
# 1          4.40     711,792 ratings
# 2          4.51     652,030 ratings
# 3          3.99   1,955,059 ratings
# 4          4.46   1,144,921 ratings
# ..          ...                 ...
# 95         3.86      86,798 ratings
# 96         4.13      62,571 ratings
# 97         3.80      39,280 ratings
# 98         3.95     134,320 ratings
# 99         4.13      79,386 ratings
#
# [100 rows x 4 columns]

# %% [markdown]
# #### Cleaning the 'No. of Reviews' column

# %%
df['No. of Reviews'] = df['No. of Reviews'].str.replace("[^0-9]", "", regex=True)
df['No. of Reviews'] = df['No. of Reviews'].apply(lambda x: int(x))
df
# Out:
#                                                 Title               Author  \
# 0                   The Invisible Life of Addie LaRue      Victoria Schwab
# 1   The House in the Cerulean Sea (Cerulean Chroni...           T.J. Klune
# 2                                   Project Hail Mary            Andy Weir
# 3                                The Midnight Library            Matt Haig
# 4                                I'm Glad My Mom Died     Jennette McCurdy
# ..                                                ...                  ...
# 95                                  Oona Out of Order  Margarita Montimore
# 96                             The Death of Vivek Oji        Akwaeke Emezi
# 97                                  The Hollow Places        T. Kingfisher
# 98                                         The Switch         Beth O'Leary
# 99                                         Migrations  Charlotte McConaghy
#
#     Avg. Rating  No. of Reviews
# 0          4.18         1176362
# 1          4.40          711792
# 2          4.51          652030
# 3          3.99         1955059
# 4          4.46         1144921
# ..          ...             ...
# 95         3.86           86798
# 96         4.13           62571
# 97         3.80           39280
# 98         3.95          134320
# 99         4.13           79386
#
# [100 rows x 4 columns]

# %% [markdown]
# ### New Stats

# %%
df.describe()
# Out:
#        Avg. Rating  No. of Reviews
# count   100.000000    1.000000e+02
# mean      4.179600    4.518814e+05
# std       0.225455    4.457272e+05
# min       3.670000    6.570000e+02
# 25%       4.010000    1.432612e+05
# 50%       4.195000    2.503055e+05
# 75%       4.350000    6.343142e+05
# max       4.620000    2.038598e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           100 non-null    object
#  1   Author          100 non-null    object
#  2   Avg. Rating     100 non-null    float64
#  3   No. of Reviews  100 non-null    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.3+ KB

# %%
df.to_csv(r'C:\Users\rajan\Downloads\Datasets\Best Books of 2020s.csv', index=False)
